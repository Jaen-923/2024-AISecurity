# %% [markdown]
# # 2주차 과제
# ## 사용한 데이터셋 : winequality-red
# #### 설명 변수 : volatile acidity, alcohol
# #### 종속 변수 : quality

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# 데이터 불러오기
data_url = "/Users/ogjaeeun/Downloads/winequality-red.csv"

# %%
data = pd.read_csv(data_url, skiprows=1, header=None)
data.columns = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides',
                'free sulfur dioxide','total sulfur dioxide','density','pH', 'sulphates', 'alcohol', 'quality']
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
X = data[['volatile acidity', 'alcohol']] 
y = data['quality']
X, y
# Out:
# (      volatile acidity  alcohol
#  0                0.700      9.4
#  1                0.880      9.8
#  2                0.760      9.8
#  3                0.280      9.8
#  4                0.700      9.4
#  ...                ...      ...
#  1594             0.600     10.5
#  1595             0.550     11.2
#  1596             0.510     11.0
#  1597             0.645     10.2
#  1598             0.310     11.0
#
#  [1599 rows x 2 columns],
#  0       5
#  1       5
#  2       5
#  3       6
#  4       5
#         ..
#  1594    5
#  1595    6
#  1596    6
#  1597    5
#  1598    6
#  Name: quality, Length: 1599, dtype: int64)

# %%
# 훈련 세트
X_train = data[['volatile acidity', 'alcohol']].iloc[:1439]
y_train = data['quality'].iloc[:1439]

# 테스트 세트 
X_test = data[['volatile acidity', 'alcohol']].iloc[1439:]
y_test = data['quality'].iloc[1439:]

X_train, X_test
# Out:
# (      volatile acidity  alcohol
#  0                0.700      9.4
#  1                0.880      9.8
#  2                0.760      9.8
#  3                0.280      9.8
#  4                0.700      9.4
#  ...                ...      ...
#  1434             0.540      9.0
#  1435             0.540      9.0
#  1436             0.380      8.5
#  1437             0.915     11.1
#  1438             0.590     10.3
#
#  [1439 rows x 2 columns],
#        volatile acidity    alcohol
#  1439             0.670  11.066667
#  1440             0.370  11.300000
#  1441             0.785   9.566667
#  1442             0.630   9.800000
#  1443             0.580  11.700000
#  ...                ...        ...
#  1594             0.600  10.500000
#  1595             0.550  11.200000
#  1596             0.510  11.000000
#  1597             0.645  10.200000
#  1598             0.310  11.000000
#
#  [160 rows x 2 columns])

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42) # 9:1 비율로 나누기
# X_train, X_test

# %%
model = LinearRegression()
model.fit(X_train, y_train) # trainset으로 fitting
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 3.081250462085353

# %%
model.coef_
# Out:
# array([-1.36034681,  0.31469111])

# %%
def predict(x, model=None):
    return sum(model.coef_ * x) + model.intercept_

y_pred = predict(data[['volatile acidity', 'alcohol']].iloc[1004], model=model)
y_pred
# Out:
# 5.73761974670903

# %%
model.predict(data[['volatile acidity', 'alcohol']].iloc[1004].values.reshape(1, -1))[0]
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 5.73761974670903

# %%
y_pred == model.predict(data[['volatile acidity', 'alcohol']].iloc[[1004]])
# Out:
# array([ True])

# %%
y_pred, data[['volatile acidity', 'alcohol']].iloc[1004].values[0]
# Out:
# (5.73761974670903, 0.43)

# %%
for i in range(500, 506):
    print(f'index: {i}', predict(data[['volatile acidity', 'alcohol']].iloc[i], model=model), data.iloc[i, -1])
# Out:
# index: 500 5.206090092952823 6
# index: 501 6.258991162460328 7
# index: 502 6.258991162460328 7
# index: 503 6.157693369766948 7
# index: 504 6.153431195204655 7
# index: 505 6.348319375906992 7

# %%
model.score(X_test, y_test) # testset의 결정계수 확인
# Out:
# 0.2607504899259707

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# 회귀식 계수 및 절편
w1, w2 = model.coef_
b = model.intercept_

def regression_func(x, y):
    return w1 * x + w2 * y + b

# 그래프 생성
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
x = X_train['volatile acidity']
y = X_train['alcohol']
z = regression_func(x, y)
ax.scatter(x, y, y_train, color='g', marker='^')  # 실제 데이터 점으로 표시
ax.plot_trisurf(x, y, z, color='y', alpha=0.5)  

ax.set_xlabel('Volatile Acidity')
ax.set_ylabel('Alcohol')
ax.set_zlabel('Quality')

plt.show()

# %%
from sympy import symbols
from sympy.plotting import plot3d

x, y = symbols('x y')

w1, w2 = model.coef_
b = model.intercept_
regression_equation = w1 * x + w2 * y + b

p4 = plot3d(regression_equation, (x, X_test['volatile acidity'].min(), X_test['volatile acidity'].max()), 
            (y, X_test['alcohol'].min(), X_test['alcohol'].max()), xlabel='Volatile Acidity', ylabel='Alcohol', show=False)

p4.show()
